# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]  # aqui não são índics (como se fosse um array) e sim labels
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# ...

# %%
df.loc[[10,40]]  # pegando os dados das linhas 10 e 40
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              39789               39789               39789
# 40              39158               39158               39158
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               39789               39789                INCIDENTE
# 40               39158               39158                INCIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 NaN                  NaN  SÃO PEDRO DO SUL            RS
# 40                 ***                  ***             BELÉM            PA
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2010-01-10        21:30:00                            ***
# 40  ...     2010-01-28        16:00:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10                 NaN                         NaN
# ...

# %%
df.loc[:,'ocorrencia_cidade']  # trazendo somente os dados de uma coluna
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
df.codigo_ocorrencia.is_unique  # verificando se a coluna codigo_ocorrencia tem valores únicos para linhas diferentes
# Out:
# True

# %%
df.ocorrencia_uf.is_unique
# Out:
# False

# %%
df.set_index('codigo_ocorrencia')  # definindo uma coluna como índice no dataframe no momento de execução (não faz alteração)
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
# ...                               ...                 ...                 ...
# 80245                           80245               80245               80245
# 80247                           80247               80247               80247
# 80251                           80251               80251               80251
# 80257                           80257               80257               80257
# 80259                           80259               80259               80259
#
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# ...

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia1                              40324
# codigo_ocorrencia2                              40324
# codigo_ocorrencia3                              40324
# codigo_ocorrencia4                              40324
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               NaN
# ocorrencia_longitude                              NaN
# ocorrencia_cidade                             PELOTAS
# ocorrencia_uf                                      RS
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBPK
# ocorrencia_dia                    2010-01-05 00:00:00
# ocorrencia_hora                              19:25:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       NaN
# divulgacao_relatorio_publicado                    NÃO
# ...

# %%
df.reset_index(drop=True, inplace=True)  # resetando o índice padrão

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %% [markdown]
# ALTERANDO OS DADOS

# %%
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2010-01-03        12:00:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista,,
# 0                   0                           1                     NÃO,,
#
# [1 rows x 21 columns]

# %%
df.loc[1] = 20  # alterando o dado para uma única linha em todas as colunas

# %%
df.head(2)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1                  20                       20                  20
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
# 1                   20                20            20              20  ...
#
#         ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  2010-01-03 00:00:00        12:00:00                            SIM
# 1                   20              20                             20
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# ...

# %%
df.loc[:,'total_recomendacoes'] = 10  # alterando o dado para uma única coluna em todas as linhas

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                     20                  20                  20
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 6109               80245               80245               80245
# 6110               80247               80247               80247
# 6111               80251               80251               80251
# 6112               80257               80257               80257
# 6113               80259               80259               80259
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf  # backup de colunas

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                     20                  20                  20
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 6109               80245               80245               80245
# 6110               80247               80247               80247
# 6111               80251               80251               80251
# 6112               80257               80257               80257
# 6113               80259               80259               80259
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'  # alterando para 'GRAVE' as ocorrencias que têm por estado 'SP'

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                     20                  20                  20
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 6109               80245               80245               80245
# 6110               80247               80247               80247
# 6111               80251               80251               80251
# 6112               80257               80257               80257
# 6113               80259               80259               80259
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 11                 40069               40069               40069
# 16                 39809               39809               39809
# 18                 39828               39828               39828
# 26                 39847               39847               39847
# 27                 39768               39768               39768
# ...                  ...                 ...                 ...
# 6084               80234               80234               80234
# 6085               80208               80208               80208
# 6104               80238               80238               80238
# 6108               80244               80244               80244
# 6113               80259               80259               80259
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 11                 40069                    GRAVE      -23.5069444444
# ...

# %%
df  # vale lembrar que todas as alterações são feitas no dataframe, não no arquivo de origem
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrenica_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA  # ocorrencia_aerodromo recebeu o valor NAO INFORMADO onde o valor é ****

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df.replace(['**','###!','####','****','*****','NULL','***'], pd.NA, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %%
df.isna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
# ...                 ...                 ...                 ...
# 6109              False               False               False
# 6110              False               False               False
# 6111              False               False               False
# 6112              False               False               False
# 6113              False               False               False
#
#       codigo_ocorrencia3  codigo_ocorrencia4  ocorrencia_classificacao  \
# 0                  False               False                     False
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2290
# ocorrencia_longitude              2292
# ocorrencia_cidade                    0
# ocorrencia_uf                        2
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2456
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2399
# investigacao_status                341
# divulgacao_relatorio_numero       3920
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4537
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista,,             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2290
# ocorrencia_longitude              2292
# ocorrencia_cidade                    0
# ocorrencia_uf                        2
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2456
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2399
# investigacao_status                341
# divulgacao_relatorio_numero       3920
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4537
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista,,             0
# dtype: int64

# %%
df.fillna(10, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                 0
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista,,          0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                  10                   10      RIO DE JANEIRO            RJ
# ...

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2290
# ocorrencia_longitude              2292
# ocorrencia_cidade                    0
# ocorrencia_uf                        2
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2456
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2399
# investigacao_status                341
# divulgacao_relatorio_numero       3920
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4537
# total_recomendacoes                  2
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista,,             0
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2290
# ocorrencia_longitude              2292
# ocorrencia_cidade                    0
# ocorrencia_uf                        2
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2456
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2399
# investigacao_status                341
# divulgacao_relatorio_numero       3920
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4537
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista,,             0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)  # exclui a coluna total_recomendacoes_bkp

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                <NA>                 <NA>      RIO DE JANEIRO            RJ
# ...

# %%
df.dropna()  # exclui tudo onde tiver NA
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 8                 39156               39156               39156
# 11                40069               40069               40069
# 14                40107               40107               40107
# 35                39487               39487               39487
# 51                39115               39115               39115
# ...                 ...                 ...                 ...
# 5435              79329               79329               79329
# 5496              79429               79429               79429
# 5584              79536               79536               79536
# 5649              79627               79627               79627
# 5697              79692               79692               79692
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 8                  39156               39156          INCIDENTE GRAVE
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %%
df.drop_duplicates(inplace=True)  # inplace=True possibilita a ação no dataframe e não somente no momento da execução.

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...
